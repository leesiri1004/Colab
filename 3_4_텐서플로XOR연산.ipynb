# %% [markdown]
# <a href="https://colab.research.google.com/github/leesiri1004/Colab/blob/main/3_4_%ED%85%90%EC%84%9C%ED%94%8C%EB%A1%9CXOR%EC%97%B0%EC%82%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
날짜 : 2021/02/04
이름 : 이슬이
내용 : 텐서플로 XOR 연산 실습하기
"""

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
tf.__version__
# Out:
# '2.4.1'

# %%
# 데이터 준비
data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
label = np.array([[0], [1], [1], [0]])

# %%
# 학습모델 설계
model = Sequential()
model.add(Dense(units=100, input_shape=(2,), activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
# 모델 설정
model.compile(optimizer='Adam',
              loss='mean_squared_error', # 'mean_squared_error' -> mse
              metrics=['acc'])

# %%
# 학습하기
model.fit(data, label, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 301ms/step - loss: 0.2545 - acc: 0.5000
# Epoch 2/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2528 - acc: 0.5000
# Epoch 3/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2516 - acc: 0.5000
# Epoch 4/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2507 - acc: 0.5000
# Epoch 5/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2503 - acc: 0.7500
# Epoch 6/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2502 - acc: 0.5000
# Epoch 7/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2503 - acc: 0.2500
# Epoch 8/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2505 - acc: 0.5000
# Epoch 9/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2507 - acc: 0.5000
# Epoch 10/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2509 - acc: 0.5000
# Epoch 11/1000
# ...

# %%
# 검증하기
result = model.predict(data)
result
# Out:
# array([[0.14175192],
#        [0.8540338 ],
#        [0.85239995],
#        [0.15040419]], dtype=float32)
